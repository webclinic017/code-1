# %%
import pandas as pd
import csv

# %%
df = pd.read_csv('C://Users//29186//Desktop//实习//附件//金股.csv')
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10136/1959916574.py in <module>
# ----> 1 df = pd.read_csv('C://Users//29186//Desktop//实习//附件//金股.csv')
#
# C:\codeware\anaconda\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
data = csv.reader(data)

# %%
data = open('C://Users//29186//Desktop//实习//附件//金股.csv')

# %%
tmp_lst = []
with open('C://Users//29186//Desktop//实习//附件//金股数据.csv', 'r') as f:
    reader = csv.reader(f)
    for row in reader:
        tmp_lst.append(row)
df = pd.DataFrame(tmp_lst[1:], columns=tmp_lst[0]) 
print(df)
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10136/2822174794.py in <module>
#       2 with open('C://Users//29186//Desktop//实习//附件//金股数据.csv', 'r') as f:
#       3     reader = csv.reader(f)
# ----> 4     for row in reader:
#       5         tmp_lst.append(row)
#       6 df = pd.DataFrame(tmp_lst[1:], columns=tmp_lst[0])
#
# UnicodeDecodeError: 'gbk' codec can't decode byte 0x80 in position 10: illegal multibyte sequence

# %%
df
# Out:
#                     Name       所属日期             股票名称      股票代码 50周价格水平  \
# 0        2020年12月金股.xlsx  2020/12/1   盘江股份\nSH600395  SH600395   0.443
# 1        2020年12月金股.xlsx  2020/12/1   金石资源\nSH603505  SH603505  0.3582
# 2        2020年12月金股.xlsx  2020/12/1   欧派家居\nSH603833  SH603833  0.7051
# 3        2020年12月金股.xlsx  2020/12/1   中国太保\nSH601601  SH601601  0.3949
# 4        2020年12月金股.xlsx  2020/12/1   中海油服\nSH601808  SH601808  0.3315
# ...                  ...        ...              ...       ...     ...
# 6078  2021_03_part5.xlsx   2021/3/1   中国平安\nSH601318  SH601318  0.0137
# 6079  2021_03_part5.xlsx   2021/3/1  爱 婴 室\nSH603214  SH603214  0.3601
# 6080  2021_03_part5.xlsx   2021/3/1   潍柴动力\nSZ000338  SZ000338  0.2386
# 6081  2021_03_part5.xlsx   2021/3/1   三七互娱\nSZ002555  SZ002555  0.2049
# 6082  2021_03_part5.xlsx   2021/3/1   顺丰控股\nSZ002352  SZ002352  0.1922
#
#          当日涨幅     当月涨幅      调入状态 推荐家数  所属行业   市值  推荐机构 推荐逻辑 流通市值(亿元)
# ...

# %%
df['流通市值(亿元)']
# Out:
# 0
# 1
# 2
# 3
# 4
#        ..
# 6078
# 6079
# 6080
# 6081
# 6082
# Name: 流通市值(亿元), Length: 6083, dtype: object
